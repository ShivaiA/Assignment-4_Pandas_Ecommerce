# %% [markdown]
# # Ecommerce Purchases Exercise

# %%
#Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom.

# %%
import pandas as pd

# %%
ecom=pd.read_csv('Ecommerce Purchases')

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# ### Check the head of the DataFrame.

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
#** How many rows and columns are there? **

# %%
ecom.shape
# Out:
# (10000, 14)

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom.size
# Out:
# 140000

# %%
ecom.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
ecom.transpose()
# Out:
#                                                                0     \
# Address           16629 Pace Camp Apt. 448\nAlexisborough, NE 77...
# Lot                                                           46 in
# AM or PM                                                         PM
# Browser Info      Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# Company                                             Martinez-Herman
# Credit Card                                        6011929061123406
# CC Exp Date                                                   02/20
# CC Security Code                                                900
# CC Provider                                            JCB 16 digit
# Email                                             pdunlap@yahoo.com
# Job                          Scientist, product/process development
# IP Address                                          149.146.147.205
# Language                                                         el
# ...

# %%
#** What is the average Purchase Price? **

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
#** What were the highest and lowest purchase prices? **

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %%
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
#** How many people have English 'en' as their Language of choice on the website? **

# %%
ecom['Language']
# Out:
# 0       el
# 1       fr
# 2       de
# 3       es
# 4       es
#         ..
# 9995    it
# 9996    pt
# 9997    el
# 9998    es
# 9999    el
# Name: Language, Length: 10000, dtype: object

# %%
lan=ecom.pivot_table(columns=['Language'],aggfunc='size')

# %%
lan
# Out:
# Language
# de    1155
# el    1137
# en    1098
# es    1095
# fr    1097
# it    1086
# pt    1118
# ru    1155
# zh    1059
# dtype: int64

# %%
lan['en']
# Out:
# 1098

# %%
ecom['Language'].value_counts()
# Out:
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
#** How many people have the job title of "Lawyer" ? **

# %%
job=ecom.pivot_table(columns=['Job'],aggfunc='size')

# %%
job
# Out:
# Job
# Academic librarian                  11
# Accommodation manager               17
# Accountant, chartered               20
# Accountant, chartered certified     18
# Accountant, chartered management    15
#                                     ..
# Water quality scientist             18
# Web designer                        20
# Wellsite geologist                  24
# Writer                              10
# Youth worker                        18
# Length: 623, dtype: int64

# %%
job['Lawyer']
# Out:
# 30

# %%
ecom['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64

# %%
#** How many people made the purchase during the AM and how many people made the purchase during PM ? **

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
#** What are the 5 most common Job Titles? **

# %%
job1=ecom['Job'].value_counts()

# %%
job1.head(5)
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: Job, dtype: int64

# %%
#** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? *

# %%
ecom1=ecom.copy()

# %%
ecom1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom1.set_index('Lot',inplace=True)

# %%
ecom1
# Out:
#                                                  Address AM or PM  \
# Lot
# 46 in  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...       PM
# 28 rn  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...       PM
# 94 vE                   Unit 0065 Box 5052\nDPO AP 27450       PM
# 36 vm              7780 Julia Fords\nNew Stacy, WA 45798       PM
# 20 IE  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...       AM
# ...                                                  ...      ...
# 92 XI      966 Castaneda Locks\nWest Juliafurt, CO 96415       PM
# 41 JY  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...       AM
# 74 Zh              Unit 4434 Box 6343\nDPO AE 28026-0283       AM
# 74 cL               0096 English Rest\nRoystad, IA 12457       PM
# 64 Hr     40674 Barrett Stravenue\nGrimesville, WI 79682       AM
#
#                                             Browser Info  \
# Lot
# 46 in  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# ...

# %%
ecom1.loc['90 WT','Purchase Price']
# Out:
# 75.1

# %%
lotn=['90 WT']
ecom[ecom['Lot'].isin(lotn)]['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
#What is the email of the person with the following Credit Card Number: 4926535242672853

# %%
ccn=['4926535242672853']
ecom[ecom['Credit Card'].isin(ccn)]
# Out:
# Empty DataFrame
# Columns: [Address, Lot, AM or PM, Browser Info, Company, Credit Card, CC Exp Date, CC Security Code, CC Provider, Email, Job, IP Address, Language, Purchase Price, yr, host]
# Index: []

# %% [markdown]
# # 4926535242672853 Credit card no not found in that column, where as seen in notepad file

# %%
#How many people have American Express as their Credit Card Provider *and made a purchase above $95 ?**

# %%
pp=ecom[(ecom['Purchase Price']>95)]

# %%
pp
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 23    25292 Shepherd Trail Apt. 798\nRussellmouth, S...  31 pS       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# ...                                                 ...    ...      ...
# 9885            82535 Gay Bypass\nNew Kathryn, AZ 05190  39 vm       PM
# 9886  037 Kelsey Knolls Suite 020\nTorresmouth, UT 5...  56 SL       AM
# 9934     52276 Smith Cliffs\nLake Vanessaview, AL 91791  40 nG       AM
# 9958                   PSC 8781, Box 4214\nAPO AP 94478  72 Ez       AM
# 9967            409 Holland Drives\nWhitetown, ME 78654  38 aX       AM
#
#                                            Browser Info  \
# ...

# %%
type(pp)
# Out:
# pandas.core.frame.DataFrame

# %%
ae=pp['CC Provider'].value_counts()

# %%
ae
# Out:
# JCB 16 digit                   84
# VISA 16 digit                  80
# Voyager                        58
# VISA 13 digit                  46
# JCB 15 digit                   45
# Mastercard                     42
# American Express               39
# Diners Club / Carte Blanche    38
# Discover                       38
# Maestro                        35
# Name: CC Provider, dtype: int64

# %%
ccpro=['American Express']
df1= ecom[(ecom['Purchase Price']>95) & ecom['CC Provider'].isin(ccpro)]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 9 to 9856
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           39 non-null     object
#  1   Lot               39 non-null     object
#  2   AM or PM          39 non-null     object
#  3   Browser Info      39 non-null     object
#  4   Company           39 non-null     object
#  5   Credit Card       39 non-null     int64
#  6   CC Exp Date       39 non-null     object
#  7   CC Security Code  39 non-null     int64
#  8   CC Provider       39 non-null     object
#  9   Email             39 non-null     object
#  10  Job               39 non-null     object
#  11  IP Address        39 non-null     object
#  12  Language          39 non-null     object
#  13  Purchase Price    39 non-null     float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 4.6+ KB

# %%
#Hard: How many people have a credit card that expires in 2025?

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom[['CC Exp Date','yr']]=ecom['CC Exp Date'].str.split('/',expand=True)

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
ecom['yr']>=25  #solved further
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
# ----> 1 ecom['yr']>=25
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:60, in OpsMixin.__ge__(self, other)
#      58 @unpack_zerodim_and_defer("__ge__")
#      59 def __ge__(self, other):
# ---> 60     return self._cmp_method(other, operator.ge)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
type(ecom['yr'])
# Out:
# pandas.core.series.Series

# %%
type(ecom['CC Exp Date'])
# Out:
# pandas.core.series.Series

# %%
ecom['yr']
# Out:
# 0       20
# 1       18
# 2       19
# 3       24
# 4       25
#         ..
# 9995    22
# 9996    25
# 9997    21
# 9998    17
# 9999    19
# Name: yr, Length: 10000, dtype: object

# %%
ecom=ecom.astype({'yr': int})

# %%
ecom['yr']
# Out:
# 0       20
# 1       18
# 2       19
# 3       24
# 4       25
#         ..
# 9995    22
# 9996    25
# 9997    21
# 9998    17
# 9999    19
# Name: yr, Length: 10000, dtype: int32

# %%
ecom[ecom['yr']==25]
# Out:
#                                                 Address    Lot AM or PM  \
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# ...                                                 ...    ...      ...
# 9955      66539 Potts Forge\nCartershire, AK 58271-5180  37 KB       AM
# 9963  3865 Davis Meadow Suite 915\nPort Stacieview, ...  11 fo       AM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
#Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...)

# %%
ecom[['Email','host']]=ecom['Email'].str.split('@',expand=True)

# %%
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
popularhost=ecom['host'].value_counts()

# %%
popularhost.head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: host, dtype: int64
